# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 2.4 MB/s eta 0:00:04
#    --- ------------------------------------ 0.8/9.9 MB 2.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.9 MB 2.3 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.9 MB 1.9 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.9 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.9 MB 2.2 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.9 MB 2.2 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/9.9 MB 2.3 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.9 MB 2.4 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.9 MB 2.4 MB/s eta 0:00:03
# ...

# %%
import plotly.express as px
data = dict(
number=[39, 27.4, 20.6, 11, 2],
stage=["Website visit", "Downloads", "Potential customers", "Requested price", "invoice sent"])
fig = px.funnel(data, x='number', y='stage')
fig.show()

# %%
pip install ffmpeg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=31e1da3529a829761542fcb052bbaac551fe719b7c6bc23eea8800bf16b443f5
#   Stored in directory: /root/.cache/pip/wheels/8e/7a/69/cd6aeb83b126a7f04cbe7c9d929028dc52a6e7d525ff56003a
# Successfully built ffmpeg
# ...

# %%
pip install bar_chart_race
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('corona_dat.csv')

# %%
df.sample()
# Out:
#         date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 74  4/5/2020           55       33       91       41       4
#
#     Antigua and Barbuda  Argentina  Armenia  Australia  ...  Uruguay     US  \
# 74                    0          2       66        198  ...       18  32468
#
#     Uzbekistan  Venezuela  Vietnam  West Bank and Gaza  Western Sahara  Yemen  \
# 74          81          4        1                  24               4      0
#
#     Zambia  Zimbabwe
# 74       1         0
#
# [1 rows x 188 columns]

# %%
df2=df[['date','China','Italy','Brazil','Spain', 'US', 'Turkey' ]]

# %%
df2.head()
# Out:
#         date  China  Italy  Brazil  Spain  US  Turkey
# 0  1/22/2020    593      0       0      0   1       0
# 1  1/23/2020     98      0       0      0   0       0
# 2  1/24/2020    291      0       0      0   1       0
# 3  1/25/2020    505      0       0      0   0       0
# 4  1/26/2020    693      0       0      0   3       0

# %%
df2.set_index('date',inplace=True)
toplam=df2.cumsum(axis=0)
toplam.head()
# Out:
#            China  Italy  Brazil  Spain  US  Turkey
# date
# 1/22/2020    593      0       0      0   1       0
# 1/23/2020    691      0       0      0   1       0
# 1/24/2020    982      0       0      0   2       0
# 1/25/2020   1487      0       0      0   2       0
# 1/26/2020   2180      0       0      0   5       0

# %%
import bar_chart_race as bcr #film oluşturuyor
bcr.bar_chart_race(toplam,filename='covid19.mp4',figsize=(10,8),title='Zafer')
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:889: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
